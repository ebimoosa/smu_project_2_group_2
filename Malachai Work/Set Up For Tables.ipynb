# %%
import pandas as pd
import numpy as np

# %%
# Reading in csv to pandas
vg_sales_df = pd.read_csv(r"C:\Users\malac\SMU\smu_project_2_group_2\Malachai Work\vg_sales_wiki.csv")

# Showing first 5
vg_sales_df
# Out:
#                              title  release_date             genre  \
# 0                        Minecraft          2009           Sandbox
# 1               Grand Theft Auto V          2013  Action Adventure
# 2                       Wii Sports          2006            Sports
# 3                Super Mario Bros.          1985        Platformer
# 4    Pokémon Red/Green/Blue/Yellow          1996               RPG
# 5    PlayerUnknown's Battlegrounds          2017     Battle Royale
# 6               Sonic the Hedgehog          1991        Platformer
# 7                          Wii Fit          2007           Fitness
# 8      Pokémon Gold/Silver/Crystal          1999               RPG
# 9              Super Mario Bros. 3          1988        Platformer
# 10             Super Mario Bros. 2          1986        Platformer
# 11                  Mario Kart Wii          2008            Racing
# 12   Pokémon Ruby/Sapphire/Emerald          2002               RPG
# ...

# %%
# Reading in csv to pandas
vg_chartz_df = pd.read_csv(r"C:\Users\malac\SMU\smu_project_2_group_2\Malachai Work\vgchartz.csv")

# Showing first 5
vg_chartz_df
# Out:
#         Rank                                             title platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#        release_date         genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vgc_genre_df = vg_chartz_df[["genre"]]
vgc_genre_df
# Out:
#               genre
# 0            Sports
# 1          Platform
# 2            Racing
# 3            Sports
# 4      Role-Playing
# ...             ...
# 16593      Platform
# 16594       Shooter
# 16595        Racing
# 16596        Puzzle
# 16597      Platform
#
# [16598 rows x 1 columns]

# %%
vgc_genre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genre   16598 non-null  object
# dtypes: object(1)
# memory usage: 129.8+ KB

# %%
vgs_genre_df = vg_sales_df[["genre"]]
vgs_genre_df
# Out:
#                genre
# 0            Sandbox
# 1   Action Adventure
# 2             Sports
# 3         Platformer
# 4                RPG
# 5      Battle Royale
# 6         Platformer
# 7            Fitness
# 8                RPG
# 9         Platformer
# 10        Platformer
# 11            Racing
# 12               RPG
# 13        Platformer
# 14            Sports
# 15        Platformer
# 16        Platformer
# 17  Lightgun Shooter
# 18             Party
# 19  Action Adventure
# 20               FPS
# 21               RPG
# 22  Action Adventure
# 23               FPS
# 24            Sports
# 25               FPS
# 26            Sports
# 27               Sim
# 28               RPG
# 29            Racing
# 30        Platformer
# 31               FPS
# 32          Fighting
# 33               FPS
# 34            Racing
# 35            Action
# 36        Platformer
# 37               Sim
# 38        Action RPG
# 39            Puzzle
# 40               FPS
# 41        Platformer
# ...

# %%
vgs_genre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   genre   51 non-null     object
# dtypes: object(1)
# memory usage: 536.0+ bytes

# %%
gender_all_df = pd.concat([vgs_genre_df, vgc_genre_df], ignore_index=True)
gender_all_df
# Out:
#                   genre
# 0               Sandbox
# 1      Action Adventure
# 2                Sports
# 3            Platformer
# 4                   RPG
# ...                 ...
# 16644          Platform
# 16645           Shooter
# 16646            Racing
# 16647            Puzzle
# 16648          Platform
#
# [16649 rows x 1 columns]

# %%
gender_list = gender_all_df.genre.unique()
gender_list
# Out:
# array(['Sandbox', 'Action Adventure', 'Sports', 'Platformer', 'RPG',
#        'Battle Royale', 'Fitness', 'Racing', 'Lightgun Shooter', 'Party',
#        'FPS', 'Sim', 'Fighting', 'Action', 'Action RPG', 'Puzzle',
#        'Racing Sim', 'Life Sim', 'Platform', 'Role-Playing', 'Misc',
#        'Shooter', 'Simulation', 'Adventure', 'Strategy'], dtype=object)

# %%
gender_csv = pd.DataFrame(gender_list)
gender_csv.to_csv(r'C:\Users\malac\SMU\Project 2\genre.csv', index=False)
gender_csv
# Out:
#                    0
# 0            Sandbox
# 1   Action Adventure
# 2             Sports
# 3         Platformer
# 4                RPG
# 5      Battle Royale
# 6            Fitness
# 7             Racing
# 8   Lightgun Shooter
# 9              Party
# 10               FPS
# 11               Sim
# 12          Fighting
# 13            Action
# 14        Action RPG
# 15            Puzzle
# 16        Racing Sim
# 17          Life Sim
# 18          Platform
# 19      Role-Playing
# 20              Misc
# 21           Shooter
# 22        Simulation
# 23         Adventure
# 24          Strategy

# %%
vgs_title_df = vg_sales_df[["title", "release_date"]]
vgs_title_df
# Out:
#                              title  release_date
# 0                        Minecraft          2009
# 1               Grand Theft Auto V          2013
# 2                       Wii Sports          2006
# 3                Super Mario Bros.          1985
# 4    Pokémon Red/Green/Blue/Yellow          1996
# 5    PlayerUnknown's Battlegrounds          2017
# 6               Sonic the Hedgehog          1991
# 7                          Wii Fit          2007
# 8      Pokémon Gold/Silver/Crystal          1999
# 9              Super Mario Bros. 3          1988
# 10             Super Mario Bros. 2          1986
# 11                  Mario Kart Wii          2008
# 12   Pokémon Ruby/Sapphire/Emerald          2002
# 13               Super Mario World          1990
# 14               Wii Sports Resort          2009
# 15           New Super Mario Bros.          2006
# 16       New Super Mario Bros. Wii          2009
# 17                       Duck Hunt          1984
# ...

# %%
vgc_title_df = vg_chartz_df[["title", "release_date"]]
vgc_title_df
# Out:
#                                                   title  release_date
# 0                                            Wii Sports        2006.0
# 1                                     Super Mario Bros.        1985.0
# 2                                        Mario Kart Wii        2008.0
# 3                                     Wii Sports Resort        2009.0
# 4                              Pokemon Red/Pokemon Blue        1996.0
# ...                                                 ...           ...
# 16593                Woody Woodpecker in Crazy Castle 5        2002.0
# 16594                     Men in Black II: Alien Escape        2003.0
# 16595  SCORE International Baja 1000: The Official Game        2008.0
# 16596                                        Know How 2        2010.0
# 16597                                  Spirits & Spells        2003.0
#
# [16598 rows x 2 columns]

# %%
title_all_df = pd.concat([vgs_title_df, vgc_title_df], ignore_index=True)
title_all_df
# Out:
#                                                   title  release_date
# 0                                             Minecraft        2009.0
# 1                                    Grand Theft Auto V        2013.0
# 2                                            Wii Sports        2006.0
# 3                                     Super Mario Bros.        1985.0
# 4                         Pokémon Red/Green/Blue/Yellow        1996.0
# ...                                                 ...           ...
# 16644                Woody Woodpecker in Crazy Castle 5        2002.0
# 16645                     Men in Black II: Alien Escape        2003.0
# 16646  SCORE International Baja 1000: The Official Game        2008.0
# 16647                                        Know How 2        2010.0
# 16648                                  Spirits & Spells        2003.0
#
# [16649 rows x 2 columns]

# %%
title_all_df.rename(columns = {'title':'name','release_date':'year'}, inplace = True)
title_all_df
# Out:
#                                                    name    year
# 0                                             Minecraft  2009.0
# 1                                    Grand Theft Auto V  2013.0
# 2                                            Wii Sports  2006.0
# 3                                     Super Mario Bros.  1985.0
# 4                         Pokémon Red/Green/Blue/Yellow  1996.0
# ...                                                 ...     ...
# 16644                Woody Woodpecker in Crazy Castle 5  2002.0
# 16645                     Men in Black II: Alien Escape  2003.0
# 16646  SCORE International Baja 1000: The Official Game  2008.0
# 16647                                        Know How 2  2010.0
# 16648                                  Spirits & Spells  2003.0
#
# [16649 rows x 2 columns]

# %%
title_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16649 entries, 0 to 16648
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    16649 non-null  object
#  1   year    16378 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 260.3+ KB

# %%
title_all_df[title_all_df["name"].duplicated()]
# Out:
#                                                    name    year
# 51                                           Wii Sports  2006.0
# 52                                    Super Mario Bros.  1985.0
# 53                                       Mario Kart Wii  2008.0
# 54                                    Wii Sports Resort  2009.0
# 57                                New Super Mario Bros.  2006.0
# ...                                                 ...     ...
# 16637                    Secret Files 2: Puritas Cordis  2009.0
# 16642                               Myst IV: Revelation  2004.0
# 16645                     Men in Black II: Alien Escape  2003.0
# 16646  SCORE International Baja 1000: The Official Game  2008.0
# 16648                                  Spirits & Spells  2003.0
#
# [5143 rows x 2 columns]

# %%
title_all_df = title_all_df.sort_values('name')
title_all_df
# Out:
#                                           name    year
# 4805                               '98 Koshien  1998.0
# 8408                .hack//G.U. Vol.1//Rebirth  2006.0
# 7158              .hack//G.U. Vol.2//Reminisce  2006.0
# 8653   .hack//G.U. Vol.2//Reminisce (jp sales)  2006.0
# 8355             .hack//G.U. Vol.3//Redemption  2007.0
# ...                                        ...     ...
# 678                               uDraw Studio  2010.0
# 15574             uDraw Studio: Instant Artist  2011.0
# 7886              uDraw Studio: Instant Artist  2011.0
# 521                 wwe Smackdown vs. Raw 2006     NaN
# 9186              ¡Shin Chan Flipa en colores!  2007.0
#
# [16649 rows x 2 columns]

# %%
title_all_df= title_all_df.drop_duplicates('name')
title_all_df
# Out:
#                                           name    year
# 4805                               '98 Koshien  1998.0
# 8408                .hack//G.U. Vol.1//Rebirth  2006.0
# 7158              .hack//G.U. Vol.2//Reminisce  2006.0
# 8653   .hack//G.U. Vol.2//Reminisce (jp sales)  2006.0
# 8355             .hack//G.U. Vol.3//Redemption  2007.0
# ...                                        ...     ...
# 16465               thinkSMART: Chess for Kids  2011.0
# 678                               uDraw Studio  2010.0
# 15574             uDraw Studio: Instant Artist  2011.0
# 521                 wwe Smackdown vs. Raw 2006     NaN
# 9186              ¡Shin Chan Flipa en colores!  2007.0
#
# [11506 rows x 2 columns]

# %%
title_all_df = title_all_df.dropna()
title_all_df
# Out:
#                                           name    year
# 4805                               '98 Koshien  1998.0
# 8408                .hack//G.U. Vol.1//Rebirth  2006.0
# 7158              .hack//G.U. Vol.2//Reminisce  2006.0
# 8653   .hack//G.U. Vol.2//Reminisce (jp sales)  2006.0
# 8355             .hack//G.U. Vol.3//Redemption  2007.0
# ...                                        ...     ...
# 14435                       thinkSMART FAMILY!  2010.0
# 16465               thinkSMART: Chess for Kids  2011.0
# 678                               uDraw Studio  2010.0
# 15574             uDraw Studio: Instant Artist  2011.0
# 9186              ¡Shin Chan Flipa en colores!  2007.0
#
# [11335 rows x 2 columns]

# %%
title_all_df.to_csv(r'C:\Users\malac\SMU\Project 2\videogame.csv', index=False)
title_all_df
# Out:
#                                           name    year
# 4805                               '98 Koshien  1998.0
# 8408                .hack//G.U. Vol.1//Rebirth  2006.0
# 7158              .hack//G.U. Vol.2//Reminisce  2006.0
# 8653   .hack//G.U. Vol.2//Reminisce (jp sales)  2006.0
# 8355             .hack//G.U. Vol.3//Redemption  2007.0
# ...                                        ...     ...
# 14435                       thinkSMART FAMILY!  2010.0
# 16465               thinkSMART: Chess for Kids  2011.0
# 678                               uDraw Studio  2010.0
# 15574             uDraw Studio: Instant Artist  2011.0
# 9186              ¡Shin Chan Flipa en colores!  2007.0
#
# [11335 rows x 2 columns]

# %%
vgc_platform_df = vg_chartz_df[["platform"]]
vgc_platform_df
# Out:
#       platform
# 0          Wii
# 1          NES
# 2          Wii
# 3          Wii
# 4           GB
# ...        ...
# 16593      GBA
# 16594       GC
# 16595      PS2
# 16596       DS
# 16597      GBA
#
# [16598 rows x 1 columns]

# %%
vgc_platform_df = vgc_platform_df.drop_duplicates()
vgc_platform_df
# Out:
#       platform
# 0          Wii
# 1          NES
# 4           GB
# 6           DS
# 15        X360
# 16         PS3
# 17         PS2
# 18        SNES
# 25         GBA
# 32         3DS
# 33         PS4
# 46         N64
# 52          PS
# 79          XB
# 83          PC
# 89        2600
# 90         PSP
# 101       XOne
# 107         GC
# 108       WiiU
# 143        GEN
# 637         DC
# 713        PSV
# 888        SAT
# 1261       SCD
# 3931        WS
# 6681        NG
# 9223      TG16
# 12635      3DO
# 13525       GG
# 14556     PCFX

# %%
platform_csv = vgc_platform_df.reset_index(drop=True)
platform_csv
# Out:
#    platform
# 0       Wii
# 1       NES
# 2        GB
# 3        DS
# 4      X360
# 5       PS3
# 6       PS2
# 7      SNES
# 8       GBA
# 9       3DS
# 10      PS4
# 11      N64
# 12       PS
# 13       XB
# 14       PC
# 15     2600
# 16      PSP
# 17     XOne
# 18       GC
# 19     WiiU
# 20      GEN
# 21       DC
# 22      PSV
# 23      SAT
# 24      SCD
# 25       WS
# 26       NG
# 27     TG16
# 28      3DO
# 29       GG
# 30     PCFX

# %%
platform_csv.to_csv(r'C:\Users\malac\SMU\Project 2\platform.csv', index=False)
platform_csv
# Out:
#    platform
# 0       Wii
# 1       NES
# 2        GB
# 3        DS
# 4      X360
# 5       PS3
# 6       PS2
# 7      SNES
# 8       GBA
# 9       3DS
# 10      PS4
# 11      N64
# 12       PS
# 13       XB
# 14       PC
# 15     2600
# 16      PSP
# 17     XOne
# 18       GC
# 19     WiiU
# 20      GEN
# 21       DC
# 22      PSV
# 23      SAT
# 24      SCD
# 25       WS
# 26       NG
# 27     TG16
# 28      3DO
# 29       GG
# 30     PCFX
