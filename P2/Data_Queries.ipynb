# %%
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
from config import key
import psycopg2

# %%
rds_connection_string = "postgres:group2@35.224.199.242:5432/postgres"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# <ipython-input-50-d72bc75a6b62>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['GameGenres',
#  'GamesReleasedPlatforms',
#  'videogames',
#  'genre',
#  'genre_id',
#  'all_games',
#  'platforms',
#  'platform_list']

# %%
conn = engine.connect()

# %%
query = """
        Select
            *
        From
            all_games;
        """

df = pd.read_sql(query, conn)
df
# Out:
#     id                                  name  critic_score  user_score  \
# 0    1                          World of Goo            94         8.8
# 1    2  Metal Gear Solid V: The Phantom Pain            95         7.4
# 2    3  Metal Gear Solid V: The Phantom Pain            95         7.4
# 3    4  Metal Gear Solid V: The Phantom Pain            95         7.4
# 4    5  Metal Gear Solid V: The Phantom Pain            95         7.4
# ..  ..                                   ...           ...         ...
# 88  89              Tony Hawk's Pro Skater 2            98         7.4
# 89  90              Tony Hawk's Pro Skater 2            98         7.4
# 90  91              Tony Hawk's Pro Skater 2            98         7.4
# 91  92  The Legend of Zelda: Ocarina of Time            99         9.2
# 92  93  The Legend of Zelda: Ocarina of Time            99         9.2
#
#    platform    year   genre  global_sales  game_id                last_update
# 0        PC  2008.0  Puzzle          0.04        0 2022-03-22 18:14:01.576050
# 1       PS4  2015.0  Action          3.38        1 2022-03-22 18:14:01.576050
# 2      XOne  2015.0  Action          0.71        2 2022-03-22 18:14:01.576050
# 3       PS3  2015.0  Action          0.70        3 2022-03-22 18:14:01.576050
# 4      X360  2015.0  Action          0.21        4 2022-03-22 18:14:01.576050
# ..      ...     ...     ...           ...      ...                        ...
# 88       PS  2000.0  Sports          4.68       88 2022-03-22 18:14:01.576050
# 89      GBA  2001.0  Sports          1.18       89 2022-03-22 18:14:01.576050
# 90      N64  2001.0  Sports          0.76       90 2022-03-22 18:14:01.576050
# 91      N64  1998.0  Action          7.60       91 2022-03-22 18:14:01.576050
# 92      3DS  2011.0  Action          4.21       92 2022-03-22 18:14:01.576050
#
# [93 rows x 10 columns]

# %%
df = df.drop(["id", "platform", 'genre', "last_update"], axis=1)
df.head()
# Out:
#                                    name  critic_score  user_score    year  \
# 0                          World of Goo            94         8.8  2008.0
# 1  Metal Gear Solid V: The Phantom Pain            95         7.4  2015.0
# 2  Metal Gear Solid V: The Phantom Pain            95         7.4  2015.0
# 3  Metal Gear Solid V: The Phantom Pain            95         7.4  2015.0
# 4  Metal Gear Solid V: The Phantom Pain            95         7.4  2015.0
#
#    global_sales  game_id
# 0          0.04        0
# 1          3.38        1
# 2          0.71        2
# 3          0.70        3
# 4          0.21        4

# %%
df.columns
# Out:
# Index(['name', 'critic_score', 'user_score', 'year', 'global_sales',
#        'game_id'],
#       dtype='object')

# %%
df.to_csv("Final_allgames.csv", index=False)

# %%
query2 = """
        Select
            *
        From
            videogames;
        """

df = pd.read_sql(query2, conn)
df
# Out:
#     id                name platform    year     genre  global_sales  \
# 0    1  Grand Theft Auto V      PS3  2013.0    Action         21.40
# 1    2  Grand Theft Auto V     X360  2013.0    Action         16.38
# 2    3  Grand Theft Auto V      PS4  2014.0    Action         11.98
# 3    4  Grand Theft Auto V     XOne  2014.0    Action          5.08
# 4    5  Grand Theft Auto V       PC  2015.0    Action          1.08
# ..  ..                 ...      ...     ...       ...           ...
# 88  89      The Orange Box      PS3  2007.0   Shooter          1.08
# 89  90      The Orange Box       PC  2007.0   Shooter          0.14
# 90  91             NFL 2K1       DC  2000.0    Sports          1.09
# 91  92         SoulCalibur       DC  1999.0  Fighting          0.34
# 92  93        World of Goo       PC  2008.0    Puzzle          0.04
#
#     critic_score  user_score               last_updated
# 0           96.0         7.8 2022-03-22 02:37:36.232415
# 1           96.0         7.8 2022-03-22 02:37:36.232415
# 2           96.0         7.8 2022-03-22 02:37:36.232415
# 3           96.0         7.8 2022-03-22 02:37:36.232415
# 4           96.0         7.8 2022-03-22 02:37:36.232415
# ..           ...         ...                        ...
# 88          96.0         9.2 2022-03-22 02:37:36.232415
# 89          96.0         9.2 2022-03-22 02:37:36.232415
# 90          97.0         6.3 2022-03-22 02:37:36.232415
# 91          98.0         8.6 2022-03-22 02:37:36.232415
# 92          94.0         8.8 2022-03-22 02:37:36.232415
#
# [93 rows x 9 columns]

# %%
query3 = """
        Select
            *
        From
            platforms;
        """

df = pd.read_sql(query3, conn)
df
# Out:
#     id platform               last_updated
# 0    1      PS3 2022-03-22 02:48:42.762126
# 1    2     X360 2022-03-22 02:48:42.762126
# 2    3      PS4 2022-03-22 02:48:42.762126
# 3    4     XOne 2022-03-22 02:48:42.762126
# 4    5       PC 2022-03-22 02:48:42.762126
# 5    6      PS2 2022-03-22 02:48:42.762126
# 6    7       XB 2022-03-22 02:48:42.762126
# 7    8      Wii 2022-03-22 02:48:42.762126
# 8    9       PS 2022-03-22 02:48:42.762126
# 9   10      N64 2022-03-22 02:48:42.762126
# 10  11      3DS 2022-03-22 02:48:42.762126
# 11  12       GC 2022-03-22 02:48:42.762126
# 12  13      PSP 2022-03-22 02:48:42.762126
# 13  14     WiiU 2022-03-22 02:48:42.762126
# 14  15      GBA 2022-03-22 02:48:42.762126
# 15  16     SNES 2022-03-22 02:48:42.762126
# 16  17       DC 2022-03-22 02:48:42.762126

# %%
queryg = """
        Select
            *
        From
            Genre;
        """

df = pd.read_sql(queryg, conn)
df
# Out:
#    id         genre               last_updated
# 0   1        Puzzle 2022-03-22 17:46:06.816234
# 1   2        Action 2022-03-22 17:46:06.816234
# 2   3       Shooter 2022-03-22 17:46:06.816234
# 3   4        Sports 2022-03-22 17:46:06.816234
# 4   5        Racing 2022-03-22 17:46:06.816234
# 5   6      Platform 2022-03-22 17:46:06.816234
# 6   7  Role-Playing 2022-03-22 17:46:06.816234
# 7   8      Fighting 2022-03-22 17:46:06.816234

# %%
query4 = """
        Select
            a.game_id, p.platform_id
        From
            all_games as a
        inner join platforms as p on a.platform=p.platform;
            """

platform_id = pd.read_sql(query4, conn)
platform_id.head()
# Out:
#    game_id  platform_id
# 0        0            0
# 1        1            1
# 2        2            2
# 3        3            3
# 4        4            4

# %%
platform_id.to_csv("plat_id.csv", index=False)

# %%
query5 = """
        Select
            a.game_id, g.genre_id
        From
            all_games as a
        inner join genre_id as g on a.genre=g.Genre;
"""
genre_id = pd.read_sql(query5, conn)
genre_id.head()
# Out:
#    game_id  genre_id
# 0        0         0
# 1        1         1
# 2        2         1
# 3        3         1
# 4        4         1

# %%
genre_id.to_csv("genre_id.csv", index=False)
